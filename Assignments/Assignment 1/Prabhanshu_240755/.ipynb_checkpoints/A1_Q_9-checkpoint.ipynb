# %% [markdown]
# # 9.1 Creating a Bar Chart showing each student’s Math score :

# %%
plt.bar(df['Name'],df['Math'])
plt.xlabel('Student Name')
plt.ylabel('Marks in Math')
plt.title('Marks of Students in Maths')
plt.show()

# %% [markdown]
# # 9.2 Create a line plot comparing all 4 subjects for each student
# # 9.3 Adding proper title, axis labels, and a legend to the plot.

# %%
plt.plot(df['Name'] , df['Math'] , label = 'Math')
plt.plot(df['Name'] , df['Science'] , label = 'Science')
plt.plot(df['Name'] , df['English'] , label = 'English')
plt.plot(df['Name'] , df['History'] , label = 'History')
plt.xlabel('Student')
plt.ylabel('Marks')
plt.legend()
plt.show()
